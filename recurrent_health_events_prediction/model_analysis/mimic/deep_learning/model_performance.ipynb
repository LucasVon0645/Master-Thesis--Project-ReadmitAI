# %% [markdown]
# # Model Performance Report

# %%
# %pip install pandas numpy plotly kaleido
# Out:
# Requirement already satisfied: pandas in c:\users\lucas\appdata\local\programs\python\python311\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy in c:\users\lucas\appdata\local\programs\python\python311\lib\site-packages (2.3.5)
# Requirement already satisfied: plotly in c:\users\lucas\appdata\local\programs\python\python311\lib\site-packages (6.5.0)
# Requirement already satisfied: kaleido in c:\users\lucas\appdata\local\programs\python\python311\lib\site-packages (1.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lucas\appdata\roaming\python\python311\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lucas\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lucas\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\lucas\appdata\local\programs\python\python311\lib\site-packages (from plotly) (2.12.0)
# Requirement already satisfied: packaging in c:\users\lucas\appdata\roaming\python\python311\site-packages (from plotly) (24.2)
# Requirement already satisfied: choreographer>=1.1.1 in c:\users\lucas\appdata\local\programs\python\python311\lib\site-packages (from kaleido) (1.2.1)
# Requirement already satisfied: logistro>=1.0.8 in c:\users\lucas\appdata\local\programs\python\python311\lib\site-packages (from kaleido) (2.0.1)
# Requirement already satisfied: orjson>=3.10.15 in c:\users\lucas\appdata\local\programs\python\python311\lib\site-packages (from kaleido) (3.11.4)
# Requirement already satisfied: pytest-timeout>=2.4.0 in c:\users\lucas\appdata\local\programs\python\python311\lib\site-packages (from kaleido) (2.4.0)
# Requirement already satisfied: simplejson>=3.19.3 in c:\users\lucas\appdata\local\programs\python\python311\lib\site-packages (from choreographer>=1.1.1->kaleido) (3.20.2)
# Requirement already satisfied: pytest>=7.0.0 in c:\users\lucas\appdata\local\programs\python\python311\lib\site-packages (from pytest-timeout>=2.4.0->kaleido) (9.0.1)
# Requirement already satisfied: six>=1.5 in c:\users\lucas\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: colorama>=0.4 in c:\users\lucas\appdata\roaming\python\python311\site-packages (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido) (0.4.6)
# Requirement already satisfied: iniconfig>=1.0.1 in c:\users\lucas\appdata\local\programs\python\python311\lib\site-packages (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in c:\users\lucas\appdata\local\programs\python\python311\lib\site-packages (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in c:\users\lucas\appdata\roaming\python\python311\site-packages (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido) (2.18.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

# %%
# Data from report
data = {
    "model": [
        "GRUNet",
        "SimpleAttnPool",
        "MultiHeadAttnPool",
        "SimpleAttnPool<br>CurrQuery",
        "Random Forest",
        "Logistic Regression",
    ],
    "auc_last_events": [
        0.619,  # GRUNet
        0.608,  # SimpleAttnPool
        0.605,  # MultiHeadAttnPool
        0.601,  # SimpleAttnPoolCurrQuery
        0.634,  # Random Forest
        0.618,  # Logistic Regression
    ],
    "type": [
        "Deep Learning",
        "Deep Learning",
        "Deep Learning",
        "Deep Learning",
        "Classical ML",
        "Classical ML",
    ],
}

df = pd.DataFrame(data)

df = df.sort_values(by="auc_last_events", ascending=False)
df
# Out:
#                          model  auc_last_events           type
# 4                Random Forest            0.634   Classical ML
# 0                       GRUNet            0.619  Deep Learning
# 5          Logistic Regression            0.618   Classical ML
# 1               SimpleAttnPool            0.608  Deep Learning
# 2            MultiHeadAttnPool            0.605  Deep Learning
# 3  SimpleAttnPool<br>CurrQuery            0.601  Deep Learning

# %%
fig = px.bar(
    df,
    x="model",
    y="auc_last_events",
    color="type",
    labels={"model": "Model", "auc_last_events": "AUC Score", "type": "Model Type"},
    title="Final Model Performance",
    width=1100,
    height=400,
    category_orders={"model": df["model"].tolist()},
)

fig.update_traces(
    texttemplate="%{y:.3f}",
    textposition="outside"
)

fig.update_yaxes(
    range=[0.5, df["auc_last_events"].max() + 0.03],
    tickformat=".3f",       # 3 decimal places
    dtick=0.02,            # spacing between ticks
)

# general layout adjustments
fig.update_layout(
    template="plotly_white",
    #title=dict(x=0.5, xanchor="center"),  # center title
    xaxis_title="Model",
    yaxis_title="AUC Score",
    font=dict(family="Arial", size=18),
    plot_bgcolor="rgba(0,0,0,0)",
    margin=dict(t=60, b=60, l=60, r=30),
    legend=dict(
        title="Model Type",
        orientation="h",
        font=dict(size=18),
        yanchor="bottom",
        y=1.02,
        xanchor="right",
        x=1
    )
)

fig.update_xaxes(
    tickangle=0,
    automargin=True
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\formatters.py:984, in IPythonDisplayFormatter.__call__(self, obj)
#     982 method = get_real_method(obj, self.print_method)
#     983 if method is not None:
# --> 984     method()
#     985     return True
#
# File c:\Users\lucas\AppData\Local\Programs\Python\Python311\Lib\site-packages\plotly\basedatatypes.py:850, in BaseFigure._ipython_display_(self)
#     847 import plotly.io as pio
#     849 if pio.renderers.render_on_display and pio.renderers.default:
# --> 850     pio.show(self)
#     851 else:
#     852     print(repr(self))
#
# File c:\Users\lucas\AppData\Local\Programs\Python\Python311\Lib\site-packages\plotly\io\_renderers.py:415, in show(fig, renderer, validate, **kwargs)
#     410     raise ValueError(
#     411         "Mime type rendering requires ipython but it is not installed"
#     412     )
#     414 if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 415     raise ValueError(
#     416         "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     417     )
#     419 display_jupyter_version_warnings()
#     421 ipython_display.display(bundle, raw=True)
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
# Figure({
#     'data': [{'hovertemplate': 'Model Type=Classical ML<br>Model=%{x}<br>AUC Score=%{y}<extra></extra>',
#               'legendgroup': 'Classical ML',
#               'marker': {'color': '#636efa', 'pattern': {'shape': ''}},
#               'name': 'Classical ML',
#               'orientation': 'v',
#               'showlegend': True,
#               'textposition': 'outside',
#               'texttemplate': '%{y:.3f}',
#               'type': 'bar',
#               'x': array(['Random Forest', 'Logistic Regression'], dtype=object),
#               'xaxis': 'x',
#               'y': {'bdata': 'fT81XrpJ5D8tsp3vp8bjPw==', 'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'hovertemplate': 'Model Type=Deep Learning<br>Model=%{x}<br>AUC Score=%{y}<extra></extra>',
#               'legendgroup': 'Deep Learning',
#               'marker': {'color': '#EF553B', 'pattern': {'shape': ''}},
#               'name': 'Deep Learning',
#               'orientation': 'v',
#               'showlegend': True,
#               'textposition': 'outside',
#               'texttemplate': '%{y:.3f}',
#               'type': 'bar',
#               'x': array(['GRUNet', 'SimpleAttnPool', 'MultiHeadAttnPool',
#                           'SimpleAttnPool<br>CurrQuery'], dtype=object),
#               'xaxis': 'x',
#               'y': {'bdata': 'AiuHFtnO4z/b+X5qvHTjP1yPwvUoXOM/CKwcWmQ74z8=', 'dtype': 'f8'},
#               'yaxis': 'y'}],
#     'layout': {'barmode': 'relative',
#                'font': {'family': 'Arial', 'size': 18},
#                'height': 400,
#                'legend': {'font': {'size': 18},
#                           'orientation': 'h',
#                           'title': {'text': 'Model Type'},
#                           'tracegroupgap': 0,
#                           'x': 1,
#                           'xanchor': 'right',
#                           'y': 1.02,
#                           'yanchor': 'bottom'},
#                'margin': {'b': 60, 'l': 60, 'r': 30, 't': 60},
#                'plot_bgcolor': 'rgba(0,0,0,0)',
#                'template': '...',
#                'title': {'text': 'Final Model Performance'},
#                'width': 1100,
#                'xaxis': {'anchor': 'y',
#                          'automargin': True,
#                          'categoryarray': [Random Forest, GRUNet, Logistic
#                                            Regression, SimpleAttnPool,
#                                            MultiHeadAttnPool,
#                                            SimpleAttnPool<br>CurrQuery],
#                          'categoryorder': 'array',
#                          'domain': [0.0, 1.0],
#                          'tickangle': 0,
#                          'title': {'text': 'Model'}},
#                'yaxis': {'anchor': 'x',
#                          'domain': [0.0, 1.0],
#                          'dtick': 0.02,
#                          'range': [0.5, 0.664],
#                          'tickformat': '.3f',
#                          'title': {'text': 'AUC Score'}}}
# })

# %%
fig.write_image(
    "my_plot.png",
    width=1100,   # increase for higher resolution
    height=400,   # proportional height
    scale=3       # multiplies resolution (3–5 is typical for HQ)
)
